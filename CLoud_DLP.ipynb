# %%
import re
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from sklearn.model_selection import train_test_split

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.layers import Dense
from keras import utils as np_utils
from keras.utils.np_utils import to_categorical
import warnings

from sklearn.metrics import confusion_matrix #confusion matrix declaration
from sklearn.metrics import accuracy_score   #Accuracy score matrix
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score
import pyexcel as pe
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import pandas
from sklearn import model_selection
from sklearn.linear_model import LinearRegression

#ignore warnings
warnings.filterwarnings('ignore')

#trainign data sets for the Model

data =pd.read_csv("C://Users/Oscar Okwero/Desktop/dissertation/Data/MachineLearningCSV/MachineLearningCVE/Exfiltration_Attack.csv")
DDos =pd.read_csv("C://Users/Oscar Okwero/Desktop/dissertation/Data/MachineLearningCSV/MachineLearningCVE/DDOS_Attack.csv")

data['type']=1
DDos['type']=0

Datas = data.append(DDos,ignore_index=True)

X=Datas.ix[:,0:11]
y=np.ravel(Datas.type)

#The data set devided into 2 sets ,training 0.6 and test 0.3

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)


#Model Definition
from sklearn.preprocessing import StandardScaler


#Model configuration
model =Sequential()
model.add(Dense(12,activation ='relu',input_shape =(11,)))

model.add(Dense(8,activation ='relu'))
model.add(Dense(1,activation ='sigmoid'))


#Model compilation & Training
model.compile(loss='binary_crossentropy',
              optimizer='adam',
             metrics=['accuracy'])
                   
model.fit(X_train, y_train,epochs=20, batch_size=1, verbose=1)


#Model prediction
model_pred = model.predict(X_test)
print(model_pred )


#Model Evaluation
score = model.evaluate(X_test, y_test,verbose=1)
print(score)

#Confusion matrix
matrix = confusion_matrix(Y_test, model_pred)
print(matrix)

#Classification report

report = classification_report(Y_test, model_pred)
print(report)

array = Datas.values
X = array[:,0:13]
Y = array[:,13]
seed = 7
kfold = model_selection.KFold(n_splits=10, random_state=seed)
model = LinearRegression()
scoring = 'neg_mean_absolute_error'
results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print("MAE: %.3f (%.3f)") % (results.mean(), results.std())
#

#The captured anomalous packet is analysed for presence of sensitive data

Input_String = open("C://Users/Oscar Okwero/Desktop/dissertation/Data/test.txt", "r")

string =Input_String.read() 

#def test_All(Input_String):

email_reg ='\S+@\S+'
phone_reg ='\d+'
zip_reg ="(\b\d{5}-\d{4}\b|\b\d{5}\b\s)"
credit_Card_reg ='(\b\d{5}-\d{4}\b|\b\d{5}\b\s)'
SSN_reg ='^(?!000|666)[0-8][0-9]{2}-(?!00)[0-9]{2}-(?!0000)[0-9]{4}$'
DOB_reg ="^([1-9] |1[0-9]| 2[0-9]|3[0-1])(.|-)([1-9] |1[0-2])(.|-|)20[0-9][0-9]$"

string = string.split()
for string in string:
    # print(string)
    matches= re.findall(email_reg, string) #Test for the presence of email addresses
    if len(matches)>0:
        print("Found Email Addresses :" ,matches)
    
  
    matches= re.findall(phone_reg, string) #Test for the presence of Phone Numbers
    if len(matches)>0:
        print("Found Phone Numbers :" ,matches)
  
 
    matches= re.findall(zip_reg,string) #Test for ZIP codes
    if len(matches)>0:
        print("Found ZIP code Information :" ,matches)
    
 
    matches= re.findall(credit_Card_reg, string) #Test for credit card numbers
    if len(matches)>0:
        print("Found Credit card Information :" ,matches)
    

    matches= re.findall(SSN_reg, string) #Test for Social Security Numbers
    if len(matches)>0:
        print("Found Social Security Numbers :" ,matches)
    
 
    matches= re.findall(DOB_reg, string) #Test for the presence of email addresses
    if len(matches)>0:
        print("Found Date of Birth Information :" ,matches)
# Out:
# Epoch 1/20
# 360042/360042 [==============================] - 943s 3ms/step - loss: 3.0239 - acc: 0.7111
# Epoch 2/20
# 360042/360042 [==============================] - 748s 2ms/step - loss: 1.5388 - acc: 0.7743
# Epoch 3/20
# 360042/360042 [==============================] - 760s 2ms/step - loss: 1.3972 - acc: 0.7749
# Epoch 4/20
#  26982/360042 [=>............................] - ETA: 24:50:53 - loss: 1.2035 - acc: 0.7801
